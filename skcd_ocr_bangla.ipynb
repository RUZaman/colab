# %% [markdown]
# <a href="https://colab.research.google.com/github/RUZaman/colab/blob/main/skcd_ocr_bangla.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# https://www.youtube.com/watch?v=Gi8Z5cjoNfY

# %%
# !sudo apt install tesseract-ocr
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 27 not upgraded.
# Need to get 4,850 kB of archives.
# After this operation, 16.3 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu focal/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1 [1,598 kB]
# Get:2 http://archive.ubuntu.com/ubuntu focal/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu focal/universe amd64 tesseract-ocr amd64 4.1.1-2build2 [262 kB]
# Fetched 4,850 kB in 0s (27.4 MB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %% [markdown]
# https://github.com/tesseract-ocr/tessdata_best/tree/main/script
#
#
# bengali.tessdata contain this link

# %%
# !tesseract /content/scan.jpg stdout -l En
# Out:
# Error opening data file /usr/share/tesseract-ocr/4.00/tessdata/En.traineddata
# Please make sure the TESSDATA_PREFIX environment variable is set to your "tessdata" directory.
# Failed loading language 'En'
# Tesseract couldn't load any languages!
# Could not initialize tesseract.

# %%
# %cd /usr/share/tesseract-ocr/4.00/tessdata/
# Out:
# /usr/share/tesseract-ocr/4.00/tessdata

# %%
# !wget https://github.com/tesseract-ocr/tessdata_best/raw/main/script/Bengali.traineddata
# Out:
# --2023-01-30 05:53:08--  https://github.com/tesseract-ocr/tessdata_best/raw/main/script/Bengali.traineddata
# Resolving github.com (github.com)... 140.82.113.4
# Connecting to github.com (github.com)|140.82.113.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/tesseract-ocr/tessdata_best/main/script/Bengali.traineddata [following]
# --2023-01-30 05:53:08--  https://raw.githubusercontent.com/tesseract-ocr/tessdata_best/main/script/Bengali.traineddata
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16711376 (16M) [application/octet-stream]
# Saving to: ‘Bengali.traineddata’
#
# Bengali.traineddata 100%[===================>]  15.94M  --.-KB/s    in 0.05s
#
# ...

# %%
# !pwd
# Out:
# /usr/share/tesseract-ocr/4.00/tessdata

# %%
# %cd /content/
# Out:
# /content

# %% [markdown]
# keep the scanjpg or your test image on the colab content folder and before running the next cell make current directory /content/

# %%
# !tesseract scan.jpg stdout -l Bengali  #work
# Out:
# ...
# Estimating resolution as 172
# MMMM
# MY70 BMW

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !tesseract img.jpg stdout -l Bengali   #work
# Out:
# ...
# Estimating resolution as 284
# আজ সোমবার ১৬ই মাঘ
# ১৪২৯ বঙ্গাব্দ,
#
# ৩০,জানুয়ারি-২০২৩

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# !tesseract wiki.png stdout -l Bengali
# Out:
# Error, cannot read input file wiki.png: No such file or directory
# Error during processing.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
